# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data/cleaned_data.csv')
df
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type  ac
# 0        28.0      5.0     26         21.5            12      E10   0
# 1        12.0      4.2     30         21.5            13      E10   0
# 2        11.2      5.5     38         21.5            15      E10   0
# 3        12.9      3.9     36         21.5            14      E10   0
# 4        18.5      4.5     46         21.5            15      E10   0
# ..        ...      ...    ...          ...           ...      ...  ..
# 383      16.0      3.7     39         24.5            18     SP98   0
# 384      16.1      4.3     38         25.0            31     SP98   1
# 385      16.0      3.8     45         25.0            19     SP98   0
# 386      15.4      4.6     42         25.0            31     SP98   1
# 387      14.7      5.0     25         25.0            30     SP98   1
#
# [388 rows x 7 columns]

# %%
#create new colum to check the consumption/distance ratio (l/km)

df['l/km'] = round(df['consume']/df['distance'],2)
df
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type  ac  l/km
# 0        28.0      5.0     26         21.5            12      E10   0  0.18
# 1        12.0      4.2     30         21.5            13      E10   0  0.35
# 2        11.2      5.5     38         21.5            15      E10   0  0.49
# 3        12.9      3.9     36         21.5            14      E10   0  0.30
# 4        18.5      4.5     46         21.5            15      E10   0  0.24
# ..        ...      ...    ...          ...           ...      ...  ..   ...
# 383      16.0      3.7     39         24.5            18     SP98   0  0.23
# 384      16.1      4.3     38         25.0            31     SP98   1  0.27
# 385      16.0      3.8     45         25.0            19     SP98   0  0.24
# 386      15.4      4.6     42         25.0            31     SP98   1  0.30
# 387      14.7      5.0     25         25.0            30     SP98   1  0.34
#
# [388 rows x 8 columns]

# %%
#create new colum to check the temperature delta inside the cockpit ratio temp_ratio

df['temp_delta'] = round(df['temp_inside']-df['temp_outside'],2)
df
# Out:
#      distance  consume  speed  temp_inside  temp_outside gas_type  ac  l/km  \
# 0        28.0      5.0     26         21.5            12      E10   0  0.18
# 1        12.0      4.2     30         21.5            13      E10   0  0.35
# 2        11.2      5.5     38         21.5            15      E10   0  0.49
# 3        12.9      3.9     36         21.5            14      E10   0  0.30
# 4        18.5      4.5     46         21.5            15      E10   0  0.24
# ..        ...      ...    ...          ...           ...      ...  ..   ...
# 383      16.0      3.7     39         24.5            18     SP98   0  0.23
# 384      16.1      4.3     38         25.0            31     SP98   1  0.27
# 385      16.0      3.8     45         25.0            19     SP98   0  0.24
# 386      15.4      4.6     42         25.0            31     SP98   1  0.30
# 387      14.7      5.0     25         25.0            30     SP98   1  0.34
#
#      temp_ratio  temp_delta
# ...

# %%
#now it's time to do some plots on tableau and get some insights for the next steps

# %%
df.to_csv('Data/cleaned_data2.csv',index = False)

# %%
# number of cars with SP98 and E10

df['gas_type'].value_counts()
# Out:
# SP98    228
# E10     160
# Name: gas_type, dtype: int64

# %%
#difference

dif = 228-161
dif
# Out:
# 67

# %%
# number of cars with ac
df['ac'].value_counts()
# Out:
# 0    358
# 1     30
# Name: ac, dtype: int64
